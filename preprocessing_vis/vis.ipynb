# %%
import pandas as pd
import csv

# ['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type', 
# 'Description', 'Location Description', 'Arrest', 'Domestic', 
# 'Beat', 'District', 'Ward', 'Community Area', 'FBI Code', 
# 'X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude', 'Location']
# ['Date', 'Block', 'Primary Type','Description', 'Location Description', 'Arrest', 'Domestic'
# ,'Beat', 'District', 'Ward', 'Community Area', 'FBI Code', 'Year', 'Latitude', 'Longitude', 'Location']
path = 'crime.csv'
# with open(path, 'r') as file:
#     reader = csv.reader(file)
colname = ['Latitude', 'Longitude']
data = pd.read_csv(path, header = 0, nrows = 20)
data = data.dropna(axis=0, how='all')
col_name = ['Date', 'Block', 'Primary Type']
# print(data[col_name])
print(data[data['Primary Type']=='0'])
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]

# %%
i = ['2017-01', '2017-10']
data['Date'] = pd.to_datetime(data['Date']) #将数据类型转换为日期类型
data = data.set_index('Date')
print(data)
# latitude = data['Latitude'].tolist()
# longitude = data['Longitude'].tolist() 
# print(data)
# print(" ")
# print(data[['Latitude','Longitude']])
# print(data.describe())
# print(data[(data['Year'] == 2017)])\

# 41.881832
# -87.623177
# c = (
#     Scatter()
#     .add_xaxis(latitude)
#     .add_yaxis("mean", stat['mean'].tolist())
#     .add_yaxis("stddev", stat['stddev'].tolist())
#     .add_yaxis("min", stat['min'].tolist())
#     .add_yaxis("max", stat['max'].tolist())
#     .set_global_opts(
#         title_opts=opts.TitleOpts(title="Subreddit Score", subtitle = "Statistics"),
# #         visualmap_opts=opts.VisualMapOpts(max_=50000),
#     )
# )
# c.render_notebook()
# Out:
#                            ID Case Number                      Block  IUCR  \
# Date
# 2001-01-01 11:00:00  11034701    JA366925            016XX E 86TH PL  1153
# 2017-10-08 03:00:00  11227287    JB147188         092XX S RACINE AVE   281
# 2017-03-28 14:00:00  11227583    JB147595            026XX W 79TH ST   620
# 2017-09-09 20:17:00  11227293    JB147230       060XX S EBERHART AVE   810
# 2017-08-26 10:00:00  11227634    JB147599        001XX W RANDOLPH ST   281
# 2013-02-10 00:00:00  11227517    JB138481      071XX S LAFAYETTE AVE   266
# 2015-01-01 00:01:00  11227503    JB146383       061XX S KILBOURN AVE  1751
# 2017-01-01 00:01:00  11227508    JB146365         027XX S WHIPPLE ST  1754
# 2017-07-17 10:10:00  11022695    JA353568        021XX W MC LEAN AVE   810
# 2017-12-28 15:55:00  11227633    JB147500       011XX S MICHIGAN AVE  1153
# 2017-02-10 12:00:00  11227586    JB147613  089XX S COTTAGE GROVE AVE  1310
# ...

# %%
print(data[i[0]:i[1]])
# Out:
#                            ID Case Number                      Block  IUCR  \
# Date
# 2017-10-08 03:00:00  11227287    JB147188         092XX S RACINE AVE   281
# 2017-03-28 14:00:00  11227583    JB147595            026XX W 79TH ST   620
# 2017-09-09 20:17:00  11227293    JB147230       060XX S EBERHART AVE   810
# 2017-08-26 10:00:00  11227634    JB147599        001XX W RANDOLPH ST   281
# 2017-01-01 00:01:00  11227508    JB146365         027XX S WHIPPLE ST  1754
# 2017-07-17 10:10:00  11022695    JA353568        021XX W MC LEAN AVE   810
# 2017-02-10 12:00:00  11227586    JB147613  089XX S COTTAGE GROVE AVE  1310
# 2017-07-29 15:40:00  11036284    JA370282          014XX W Devon Ave   820
# 2017-01-22 00:01:00  11227509    JB146413       079XX S JEFFERY BLVD  1752
# 2017-10-14 00:01:00  11227407    JB147329      037XX N SOUTHPORT AVE  1150
#
#                                    Primary Type  \
# Date
# 2017-10-08 03:00:00         CRIM SEXUAL ASSAULT
# ...

# %%
import sys
import os 

sys.path.append(os.path.abspath("ca/pro_data"))
print(sys.path)
# Out:
# ['C:\\Users\\91604\\Desktop\\jupyter', 'C:\\Ana\\python37.zip', 'C:\\Ana\\DLLs', 'C:\\Ana\\lib', 'C:\\Ana', '', 'C:\\Ana\\lib\\site-packages', 'C:\\Ana\\lib\\site-packages\\win32', 'C:\\Ana\\lib\\site-packages\\win32\\lib', 'C:\\Ana\\lib\\site-packages\\Pythonwin', 'C:\\Ana\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\91604\\.ipython', 'C:\\Users\\91604\\Desktop\\jupyter\\ca\\pro_data']

# %%
import read_crime

i = read_crime.Input(r'crime.csv')
print(i.data_extract(10,0))
# Out:
# 调用数据
# shape
# (10, 16)
# statistics
#               Beat   District       Ward  Community Area   FBI Code  \
# count    10.000000  10.000000  10.000000        10.00000  10.000000
# mean    803.600000   7.800000  17.400000        48.00000   6.400000
# std     648.720827   6.460134  12.212926        19.42507   5.103376
# min     122.000000   1.000000   2.000000        22.00000   2.000000
# 25%     337.750000   3.250000   9.000000        32.00000   2.000000
# 50%     772.000000   7.500000  15.500000        43.50000   5.500000
# 75%     983.500000   9.500000  20.750000        68.00000   9.750000
# max    2222.000000  22.000000  42.000000        73.00000  17.000000
#
#               Year  Latitude  Longitude  Location
# count    10.000000      10.0       10.0      10.0
# mean   2014.800000       0.0        0.0       0.0
# std       5.028806       0.0        0.0       0.0
# min    2001.000000       0.0        0.0       0.0
# 25%    2015.500000       0.0        0.0       0.0
# ...

# %%
a = "11/02/2019 11:07:32 PM"
len(a)
# Out:
# 22

# %%
plot_path = "ca/output/ca"
plot_file = "/part-00000"
import pandas as pd
#header=None:没有每列的column name，可以自己设定
#encoding='gb2312':其他编码中文显示错误
#delim_whitespace=True:用空格来分隔每行的数据
#index_col=0:设置第1列数据作为index
header = ["count"]
day = pd.read_table(plot_path+'/day'+plot_file,header=None,delim_whitespace=True)
month = pd.read_table(plot_path+'/month'+plot_file,header=None,delim_whitespace=True)
hour = pd.read_table(plot_path+'/hour'+plot_file,header=None,delim_whitespace=True)
monthday = pd.read_table(plot_path+'/monthday'+plot_file,header=None,delim_whitespace=True)
# col1 = monthday[0].astype(str) 
# col2 = monthday[1].astype(str)
# monthday['Rank'] = (col1+col2).astype(int).rank(method='dense', ascending=True).astype(int)
monthday = monthday.sort_values(by=[0,1])
monthday[0] = monthday[0].astype(str) 
monthday[1] = monthday[1].astype(str) 
monthday[0] = '2040-' + monthday[0].str.cat(monthday[1], sep = '-')
monthday[0] = pd.to_datetime(monthday[0]).apply(lambda x: x.date())
monthday = monthday.drop(columns = [1], axis=1)
mi = monthday[2].min()
ma = monthday[2].max()
print(mi)
calendar = tuple(monthday.itertuples(index=False, name=None))
calendar = [[str(x[0]), x[1]] for x in calendar]
print(calendar)

hour = hour.sort_values(by=[1,0])
hour[0] = hour[0].astype(str) 
hour[0] = hour[0].str.cat(hour[1], sep = ' ')
hour = hour.drop(columns = [1], axis=1)
print(hour)

month = month.sort_values(by=[0])
print(month)

day = day.sort_values(by=[0])
print(day)
# Out:
# 10617
# ...

# %%
a = [['2040-01-01', 29405], ['2040-01-02', 16437], ['2040-01-03', 17231], ['2040-01-04', 16869], ['2040-01-05', 17105], ['2040-01-06', 16607], ['2040-01-07', 16929], ['2040-01-08', 17213], ['2040-01-09', 17719], ['2040-01-10', 18040], ['2040-01-11', 17997], ['2040-01-12', 18084], ['2040-01-13', 17740], ['2040-01-14', 17456], ['2040-01-15', 18223], ['2040-01-16', 17631], ['2040-01-17', 17638], ['2040-01-18', 17224], ['2040-01-19', 17357], ['2040-01-20', 17246], ['2040-01-21', 16626], ['2040-01-22', 16780], ['2040-01-23', 17388], ['2040-01-24', 17311], ['2040-01-25', 17730], ['2040-01-26', 17467], ['2040-01-27', 17293], ['2040-01-28', 17221], ['2040-01-29', 16913], ['2040-01-30', 16758], ['2040-01-31', 16647], ['2040-02-01', 19363], ['2040-02-02', 16639], ['2040-02-03', 16146], ['2040-02-04', 16466], ['2040-02-05', 16591], ['2040-02-06', 16913], ['2040-02-07', 17032], ['2040-02-08', 16832], ['2040-02-09', 16916], ['2040-02-10', 16657], ['2040-02-11', 16580], ['2040-02-12', 16453], ['2040-02-13', 16740], ['2040-02-14', 17188], ['2040-02-15', 17547], ['2040-02-16', 16942], ['2040-02-17', 17041], ['2040-02-18', 17166], ['2040-02-19', 17108], ['2040-02-20', 17469], ['2040-02-21', 17371], ['2040-02-22', 17390], ['2040-02-23', 17621], ['2040-02-24', 17220], ['2040-02-25', 17379], ['2040-02-26', 16748], ['2040-02-27', 17426], ['2040-02-28', 17415], ['2040-02-29', 3945], ['2040-03-01', 21067], ['2040-03-02', 17482], ['2040-03-03', 17624], ['2040-03-04', 17244], ['2040-03-05', 17282], ['2040-03-06', 17775], ['2040-03-07', 18356], ['2040-03-08', 18327], ['2040-03-09', 18314], ['2040-03-10', 18656], ['2040-03-11', 18944], ['2040-03-12', 18901], ['2040-03-13', 18551], ['2040-03-14', 18838], ['2040-03-15', 19556], ['2040-03-16', 18981], ['2040-03-17', 19057], ['2040-03-18', 18967], ['2040-03-19', 18700], ['2040-03-20', 18625], ['2040-03-21', 18283], ['2040-03-22', 18365], ['2040-03-23', 18919], ['2040-03-24', 18951], ['2040-03-25', 18837], ['2040-03-26', 18936], ['2040-03-27', 18862], ['2040-03-28', 18805], ['2040-03-29', 18767], ['2040-03-30', 19089], ['2040-03-31', 18833
11-29', 17126], ['2040-11-30', 17381], ['2040-12-01', 19376], ['2040-12-02', 17167], ['2040-12-03', 17242], ['2040-12-04', 16737], ['2040-12-05', 16757], ['2040-12-06', 16802], ['2040-12-07', 16504], ['2040-12-08', 16259], ['2040-12-09', 16067], ['2040-12-10', 16851], ['2040-12-11', 16295], ['2040-12-12', 17211], ['2040-12-13', 17033], ['2040-12-14', 17385], ['2040-12-15', 17478], ['2040-12-16', 16531], ['2040-12-17', 16750], ['2040-12-18', 16220], ['2040-12-19', 16629], ['2040-12-20', 17184], ['2040-12-21', 16763], ['2040-12-22', 16613], ['2040-12-23', 16180], ['2040-12-24', 13582], ['2040-12-25', 10617], ['2040-12-26', 13963], ['2040-12-27', 15442], ['2040-12-28', 16043], ['2040-12-29', 15963], ['2040-12-30', 16133], ['2040-12-31', 15110]]

# %%
# month day
# calendar
import datetime

from pyecharts import options as opts
from pyecharts.charts import Calendar


def calendar_base() -> Calendar:
    data = a

    c = (
        Calendar()
        .add("", data, calendar_opts=opts.CalendarOpts(range_="2040"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Crime Frequency from 2001-2018"),
            visualmap_opts=opts.VisualMapOpts(
                max_=ma,
                min_=mi,
                orient="vertical",
                is_piecewise=True,
                pos_top="230px",
                pos_left="100px",
            ),
        )
    )
    return c
# calendar_base().render(path='./01.png')
calendar_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a9e1a9c7b136473480a3b4cd69b68787" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a9e1a9c7b136473480a3b4cd69b68787 = echarts.init(
#                     document.getElementById('a9e1a9c7b136473480a3b4cd69b68787'), 'white', {renderer: 'canvas'});
#                 var option_a9e1a9c7b136473480a3b4cd69b68787 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar


def bar_base() -> Bar:
    c = (
        Bar()
        .add_xaxis(month[0].tolist())
        .add_yaxis("Month", month[1].tolist())
        .set_global_opts(title_opts=opts.TitleOpts(title="All Crime Frequency From 2001-2018", subtitle="For Month"))
    )
    return c
bar_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d4996253d9d647cfbfb7a5d747ec842c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d4996253d9d647cfbfb7a5d747ec842c = echarts.init(
#                     document.getElementById('d4996253d9d647cfbfb7a5d747ec842c'), 'white', {renderer: 'canvas'});
#                 var option_d4996253d9d647cfbfb7a5d747ec842c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
def bar_day() -> Bar:
    c = (
        Bar()
        .add_xaxis(day[0].tolist())
        .add_yaxis("Day", day[1].tolist())
        .set_global_opts(title_opts=opts.TitleOpts(title="All Crime Frequency From 2001-2018", subtitle="For Day"))
    )
    return c
bar_day().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="48c33926421343d89bfb6886c0c039ea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_48c33926421343d89bfb6886c0c039ea = echarts.init(
#                     document.getElementById('48c33926421343d89bfb6886c0c039ea'), 'white', {renderer: 'canvas'});
#                 var option_48c33926421343d89bfb6886c0c039ea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
def bar_hour() -> Bar:
    c = (
        Bar()
        .add_xaxis(hour[0].tolist())
        .add_yaxis("Hour", hour[2].tolist())
        .set_global_opts(title_opts=opts.TitleOpts(title="All Crime Frequency From 2001-2018", subtitle="For Hour"))
    )
    return c
bar_hour().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c600e471bcee421e9a30440c2f6fbf80" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c600e471bcee421e9a30440c2f6fbf80 = echarts.init(
#                     document.getElementById('c600e471bcee421e9a30440c2f6fbf80'), 'white', {renderer: 'canvas'});
#                 var option_c600e471bcee421e9a30440c2f6fbf80 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
import random
number_of_colors = 40

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]
print(color)
# Out:
# ['#A56BFB', '#2A88EE', '#C74403', '#1E2AD3', '#D0193F', '#C6639D', '#92D1ED', '#C29CB5', '#5234EE', '#19353F', '#01F459', '#3343F9', '#B7EC05', '#7E8AF7', '#8FD724', '#A85B98', '#601C8E', '#54EC8C', '#99106E', '#5771F2', '#86D55A', '#72D9EA', '#18618B', '#F5A429', '#749A6A', '#AB217B', '#F9ABB7', '#A8022C', '#97EBF4', '#982BAD', '#BDF191', '#3D92BA', '#6EAAE1', '#72B415', '#8A571C', '#9B71F4', '#B7E47A', '#13887E', '#99F19A', '#436416']

# %%
plot_path1 = "ca/output"
plot_file = "/part-00000"
import pandas as pd
#header=None:没有每列的column name，可以自己设定
#encoding='gb2312':其他编码中文显示错误
#delim_whitespace=True:用空格来分隔每行的数据
#index_col=0:设置第1列数据作为index
day1 = pd.read_table(plot_path1+'/day/NARCOTICS'+plot_file,header=None,delim_whitespace=True)
month1 = pd.read_table(plot_path1+'/month/NARCOTICS'+plot_file,header=None,delim_whitespace=True)
hour1 = pd.read_table(plot_path1+'/hour1/NARCOTICS'+plot_file,header=None,delim_whitespace=True)
day2 = pd.read_table(plot_path1+'/day/THEFT'+plot_file,header=None,delim_whitespace=True)
month2 = pd.read_table(plot_path1+'/month/THEFT'+plot_file,header=None,delim_whitespace=True)
hour2 = pd.read_table(plot_path1+'/hour1/THEFT'+plot_file,header=None,delim_whitespace=True)
# monthday = pd.read_table(plot_path+'/monthday'+plot_file,header=None,delim_whitespace=True)
# col1 = monthday[0].astype(str) 
# col2 = monthday[1].astype(str)
# monthday['Rank'] = (col1+col2).astype(int).rank(method='dense', ascending=True).astype(int)

hour1 = hour1.sort_values(by=[1,0])
hour1[0] = hour1[0].astype(str) 
hour1[0] = hour1[0].str.cat(hour1[1], sep = ' ')
hour1 = hour1.drop(columns = [1], axis=1)
print(hour1)

month1 = month1.sort_values(by=[0])
print(month1)

day1 = day1.sort_values(by=[0])
print(day1)

hour2 = hour2.sort_values(by=[1,0])
hour2[0] = hour2[0].astype(str) 
hour2[0] = hour2[0].str.cat(hour2[1], sep = ' ')
hour2 = hour2.drop(columns = [1], axis=1)
print(hour2)

month2 = month2.sort_values(by=[0])
print(month2)

day2 = day2.sort_values(by=[0])
print(day2)
# Out:
#         0      2
# 23   1 AM  14657
# 5    2 AM   9290
# 10   3 AM   6307
# 15   4 AM   3919
# 20   5 AM   1902
# 2    6 AM   4173
# 7    7 AM   5025
# 12   8 AM  10511
# 17   9 AM  16404
# 13  10 AM  30971
# 18  11 AM  47499
# 0   12 AM  24639
# 6    1 PM  46909
# 11   2 PM  43346
# 16   3 PM  36924
# 22   4 PM  31924
# 4    5 PM  28673
# 9    6 PM  39636
# 14   7 PM  60352
# 19   8 PM  60301
# 1    9 PM  59423
# 21  10 PM  53527
# 3   11 PM  40854
# 8   12 PM  47899
#      0      1
# 3    1  63808
# 4    2  61577
# 5    3  66964
# 6    4  61687
# 7    5  61616
# 8    6  57657
# 9    7  60495
# 10   8  62855
# 11   9  59545
# 0   10  60340
# 1   11  56798
# 2   12  51723
#      0      1
# 20   1  24280
# 21   2  25232
# 22   3  25297
# 23   4  24200
# 24   5  24295
# 25   6  24929
# 26   7  24226
# 27   8  24313
# 28   9  24566
# 8   10  23908
# 9   11  24404
# 10  12  24344
# 11  13  23816
# 12  14  23442
# 13  15  23425
# 14  16  23646
# 15  17  24023
# 16  18  23089
# ...

# %%
def bar_base1() -> Bar:
    c = (
        Bar()
        .add_xaxis(month1[0].tolist())
        .add_yaxis("Month", month1[1].tolist(), color = color[1])
        .set_global_opts(title_opts=opts.TitleOpts(title="NARCOTICS Crime Frequency From 2001-2018", subtitle="For Month"))
    )
    return c
bar_base1().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ea9bce768fb64e8c96fcf2db20fa098d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ea9bce768fb64e8c96fcf2db20fa098d = echarts.init(
#                     document.getElementById('ea9bce768fb64e8c96fcf2db20fa098d'), 'white', {renderer: 'canvas'});
#                 var option_ea9bce768fb64e8c96fcf2db20fa098d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#2A88EE",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %%
def bar_day1() -> Bar:
    c = (
        Bar()
        .add_xaxis(day1[0].tolist())
        .add_yaxis("Day", day1[1].tolist(), color = color[1])
        .set_global_opts(title_opts=opts.TitleOpts(title="NARCOTICS Crime Frequency From 2001-2018", subtitle="For Day"))
    )
    return c
bar_day1().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c02ecbb89d294801be4c21168ccf86fc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c02ecbb89d294801be4c21168ccf86fc = echarts.init(
#                     document.getElementById('c02ecbb89d294801be4c21168ccf86fc'), 'white', {renderer: 'canvas'});
#                 var option_c02ecbb89d294801be4c21168ccf86fc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#2A88EE",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %%
def bar_hour1() -> Bar:
    c = (
        Bar()
        .add_xaxis(hour1[0].tolist())
        .add_yaxis("Hour", hour1[2].tolist(),  color = color[1])
        .set_global_opts(title_opts=opts.TitleOpts(title="NARCOTICS Crime Frequency From 2001-2018", subtitle="For Hour"))
    )
    return c
bar_hour1().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="58c84288837846c598515ef58c9ce255" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_58c84288837846c598515ef58c9ce255 = echarts.init(
#                     document.getElementById('58c84288837846c598515ef58c9ce255'), 'white', {renderer: 'canvas'});
#                 var option_58c84288837846c598515ef58c9ce255 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#2A88EE",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %%
def bar_base2() -> Bar:
    c = (
        Bar()
        .add_xaxis(month2[0].tolist())
        .add_yaxis("Month", month2[1].tolist(), color = color[3])
        .set_global_opts(title_opts=opts.TitleOpts(title="THEFT Crime Frequency From 2001-2018", subtitle="For Month"))
    )
    return c
bar_base2().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3a532411c0494d859a75681c0d2468a2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3a532411c0494d859a75681c0d2468a2 = echarts.init(
#                     document.getElementById('3a532411c0494d859a75681c0d2468a2'), 'white', {renderer: 'canvas'});
#                 var option_3a532411c0494d859a75681c0d2468a2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#1E2AD3",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %%
def bar_day2() -> Bar:
    c = (
        Bar()
        .add_xaxis(day2[0].tolist())
        .add_yaxis("Day", day2[1].tolist(), color = color[3])
        .set_global_opts(title_opts=opts.TitleOpts(title="TEHFT Crime Frequency From 2001-2018", subtitle="For Day"))
    )
    return c
bar_day2().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="10f10e7225e44875b9e76ffe2650b1b9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_10f10e7225e44875b9e76ffe2650b1b9 = echarts.init(
#                     document.getElementById('10f10e7225e44875b9e76ffe2650b1b9'), 'white', {renderer: 'canvas'});
#                 var option_10f10e7225e44875b9e76ffe2650b1b9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#1E2AD3",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %%
def bar_hour2() -> Bar:
    c = (
        Bar()
        .add_xaxis(hour2[0].tolist())
        .add_yaxis("Hour", hour2[2].tolist(),  color = color[3])
        .set_global_opts(title_opts=opts.TitleOpts(title="THEFT Crime Frequency From 2001-2018", subtitle="For Hour"))
    )
    return c
bar_hour2().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="80a28870c83747bd96a26b48544e2970" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_80a28870c83747bd96a26b48544e2970 = echarts.init(
#                     document.getElementById('80a28870c83747bd96a26b48544e2970'), 'white', {renderer: 'canvas'});
#                 var option_80a28870c83747bd96a26b48544e2970 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#1E2AD3",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np
from scipy.fftpack import fft,ifft
import matplotlib.pyplot as plt
import seaborn

monthday = pd.read_table(plot_path+'/monthday'+plot_file,header=None,delim_whitespace=True)
# col1 = monthday[0].astype(str) 
# col2 = monthday[1].astype(str)
# monthday['Rank'] = (col1+col2).astype(int).rank(method='dense', ascending=True).astype(int)
monthday = monthday.sort_values(by=[0,1])
monthday[0] = monthday[0].astype(str) 
monthday[1] = monthday[1].astype(str) 
monthday[0] = '2040-' + monthday[0].str.cat(monthday[1], sep = '-')
monthday[0] = pd.to_datetime(monthday[0]).apply(lambda x: x.date())
monthday = monthday.drop(columns = [1], axis=1)
mi = monthday[2].min()
ma = monthday[2].max()
monthday[2] = (monthday[2] - mi)/(ma - mi)
# df=ts.get_hist_data('000001',start='2015-02-02',end='2018-05-24')

#采样点选择1400个，因为设置的信号频率分量最高为600赫兹，根据采样定理知采样频率要大于信号频率2倍，所以这里设置采样频率为1400赫兹（即一秒内有1400个采样点，一样意思的）
x=list(range(monthday.shape[0]))   
y=list(monthday[2])  

#设置需要采样的信号，频率分量有180，390和600
#y=7*np.sin(2*np.pi*180*x) + 2.8*np.sin(2*np.pi*390*x)+5.1*np.sin(2*np.pi*600*x)

yy=fft(y)                     #快速傅里叶变换
yreal = yy.real               # 获取实数部分
yimag = yy.imag               # 获取虚数部分

yf=abs(fft(y))                # 取绝对值
yf1=abs(fft(y))/len(x)           #归一化处理
yf2 = yf1[range(int(len(x)/2))]  #由于对称性，只取一半区间

xf = np.arange(len(y))        # 频率
xf1 = xf
xf2 = xf[range(int(len(x)/2))]  #取一半区间


# plt.subplot(221)
# plt.plot(x[0:366],y[0:366])   
# plt.title('Original wave')

plt.plot(222)
plt.plot(xf,yf,'r')
plt.title('DFT of Mixed wave(two sides frequency range)',fontsize=12,color='#7A378B')  #注意这里的颜色可以查询颜色代码表

# plt.subplot(223)
# plt.plot(xf1,yf1,'g')
# plt.title('FFT of Mixed wave(normalization)',fontsize=9,color='r')

# # plt.subplot(224)
# plt.plot(xf2,yf2,'b')
# plt.title('FFT of Mixed wave)',fontsize=10,color='#F08080')


plt.show()

# %%
from pyecharts.charts import Line
def line_smooth() -> Line:
    c = (
        Line()
        .add_xaxis(x)
        .add_yaxis("Crime Line", y, is_smooth=True, color = color[4], is_symbol_show = False)
        .set_global_opts(title_opts=opts.TitleOpts(title="Criminal Wave From 2001-2018"))
    )
    return c
line_smooth().render_notebook()

# %%
def line_base() -> Line:
    c = (
        Line()
        .add_xaxis(xf1)
        .add_yaxis("商家A", xf1)
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
    )
    return c
line_base().render_notebook()

# %%
import pandas as pd
pm = 'ca/output/dbscanoutput.csv' 
map_c = pd.read_csv(pm, header = 0)
gp_col = 'labels'
x = -87.65005
y = 41.85003
a = map_c.groupby(gp_col).count()
a = a.rename(columns={'labels':'labels','x':'count','y':'a'}).drop(columns =['a'], axis = 1)['count'].tolist()
mx = map_c.groupby(gp_col)['x'].mean()
my = map_c.groupby(gp_col)['y'].mean()
cc = pd.concat([mx,my],axis=1)
c1 = cc['x'].tolist()
c2 = cc['y'].tolist() 

print(cc)
print(a)
# Out:
#                x         y
# labels
# -1      0.844251 -0.681247
#  0      0.799340 -0.586657
#  1      0.772586 -0.633424
#  2      0.993105 -0.700061
#  3      0.664184 -0.619607
#  4      0.719259 -0.591650
#  5      0.888994 -0.636025
#  6      0.851283 -0.654424
#  7      0.918949 -0.678739
#  8      0.886568 -0.729004
#  9      1.006842 -0.673373
#  10     0.895116 -0.672449
#  11     0.746372 -0.718753
#  12     0.692151 -0.627526
#  13     0.950875 -0.655345
#  14     0.975691 -0.838896
#  15     0.988078 -0.801146
#  16     0.945411 -0.688794
#  17     0.697569 -0.701834
#  18     0.931045 -0.790199
#  19     0.953519 -0.718064
#  20     0.945051 -0.818604
#  21     0.930750 -0.646435
#  22     0.789404 -0.730345
#  23     0.810020 -0.715512
#  24     0.784807 -0.768955
#  25     0.977357 -0.664104
#  26     0.909307 -0.805767
#  27     0.944408 -0.756289
#  28     0.820743 -0.693191
#  29     0.970675 -0.772602
#  30     0.696677 -0.656924
#  31     0.783914 -0.794581
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import BMap 
from pyecharts.globals import ChartType, SymbolType

# 41.87, -87.65
# Geo.add_coordinate("Chicago", 41.87, -87.65)
BAIDU_AK = "K82VhnFNsV6cOFxG5wL84i3gGm23LbhG" 
def bmap_heatmap() -> BMap:
    c = (
        BMap()
        .add_schema(baidu_ak=BAIDU_AK, center=[-87.65005, 41.85003])
        .add(
            "bmap",
            [list(z) for z in zip(cc, a)],
            type_="heatmap",
            label_opts=opts.LabelOpts(formatter="{b}"),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="BMap-热力图"),
            visualmap_opts=opts.VisualMapOpts(),
        )
    )
    return c

# %%
from pyecharts.faker import Faker
print([list(z) for z in zip(Faker.provinces, Faker.values())])
# Out:
# [['广东', 136], ['北京', 143], ['上海', 35], ['江西', 135], ['湖南', 35], ['浙江', 105], ['江苏', 21]]

# %%
print(Faker.country)
# Out:
# ['China', 'Canada', 'Brazil', 'Russia', 'United States', 'Africa', 'Germany']
